# %%
import pandas as pd
from sklearn import datasets

df_klasifikasi=pd.read_csv("iris.csv")
df_klasifikasi
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Feature selection
X=df_klasifikasi[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]

#Target
y=df_klasifikasi['Species']
print(X)
print(y)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# ## Normalize Data - Scalling

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))

# %%
print("10 data pertama: ")
print(X[:10])
# Out:
# 10 data pertama:
# [[-0.90068117  1.03205722 -1.3412724  -1.31297673]
#  [-1.14301691 -0.1249576  -1.3412724  -1.31297673]
#  [-1.38535265  0.33784833 -1.39813811 -1.31297673]
#  [-1.50652052  0.10644536 -1.2844067  -1.31297673]
#  [-1.02184904  1.26346019 -1.3412724  -1.31297673]
#  [-0.53717756  1.95766909 -1.17067529 -1.05003079]
#  [-1.50652052  0.80065426 -1.3412724  -1.18150376]
#  [-1.02184904  0.80065426 -1.2844067  -1.31297673]
#  [-1.74885626 -0.35636057 -1.3412724  -1.31297673]
#  [-1.14301691  0.10644536 -1.2844067  -1.4444497 ]]

# %%
print("10 label pertama: ")
print(y[:10])
# Out:
# 10 label pertama:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# 5    Iris-setosa
# 6    Iris-setosa
# 7    Iris-setosa
# 8    Iris-setosa
# 9    Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# # 1. Pembagian Data

# %% [markdown]
# ## 1.1 Train-Validation Split

# %% [markdown]
# Train-Validation split dapat dilakukan dengan menjalankan potongan kode di bawah. Persentase pembagian data training dan data validasi dapat ditentukan dengan mengubah nilai parameter train_size.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7)

# %%
print("Banyak data latih setelah dilakukan Train-Validation Split: ", len(X_train))
print("Banyak data uji setelah dilakukan Train-Validation Split: ", len(X_test))
# Out:
# Banyak data latih setelah dilakukan Train-Validation Split:  105
# Banyak data uji setelah dilakukan Train-Validation Split:  45

# %%
print("Label Training\n",y_train.value_counts())
print("\nLabel Prediksi\n",y_test.value_counts())
# Out:
# Label Training
#  Iris-virginica     38
# Iris-setosa        34
# Iris-versicolor    33
# Name: Species, dtype: int64
#
# Label Prediksi
#  Iris-versicolor    17
# Iris-setosa        16
# Iris-virginica     12
# Name: Species, dtype: int64

# %% [markdown]
# ## 1.2	K-Fold Cross Validation

# %% [markdown]
# Pustaka Scikit-learn menyediakan wrapper untuk melakukan K-Fold Cross Validation, yaitu dengan meng-import cross_val_score. cross_val_score menerima input berupa model machine learning, data training, label training, dan nilai K. Output yang dikeluarkan akan berupa list berisi akurasi setiap fold, sehingga untuk mendapatkan nilai rata-rata akurasi dari setiap foldnya, dapat menggunakan built-in function mean().

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

model = SVC(kernel = 'linear', C = 1)
scores = cross_val_score(model, X, y, cv = 5)
print("Akurasi model SVM untuk tiap fold: ", scores)
print("Akurasi model SVM dengan 5-Fold Cross Validation: ", scores.mean())
# Out:
# Akurasi model SVM untuk tiap fold:  [0.96666667 1.         0.93333333 0.93333333 1.        ]
# Akurasi model SVM dengan 5-Fold Cross Validation:  0.9666666666666668

# %% [markdown]
# # 2. Metode Klasifikasi

# %% [markdown]
# Untuk potongan-potongan kode Metode Klasifikasi, data yang akan digunakan adalah data yang telah terbagi oleh proses Train-Validation split. Model akan dilatih dengan X_train dan y_train. Model yang telah terlatih kemudian diuji performa akurasinya menggunakan X_test dan y_test.

# %% [markdown]
# ## 2.1 Logistic Regression

# %% [markdown]
# Penjelasan lebih lengkap mengenai penggunaan Logistic Regression dapat dilihat pada https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

lr = LogisticRegression()

lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Logistic Regression: ", score)
lr_score = score
# Out:
# Akurasi dengan menggunakan Logistic Regression:  0.9777777777777777

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(lr, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing NBC:', accuracy)

score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Logistic Regression: ", score)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing NBC: 0.9777777777777777
# Akurasi dengan menggunakan Logistic Regression:  0.9777777777777777
# Precison :  0.9743589743589745
# Recall :  0.9803921568627452
# F Score :  0.9765656565656565

# %% [markdown]
# ## 2.2 Support Vector Machine

# %% [markdown]
# Penjelasan lebih lengkap mengenai penggunaan Support Vector Machine dapat dilihat pada https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
from sklearn.svm import SVC
from sklearn import metrics

svm = SVC(
  kernel = 'rbf',
  C = 1,
  gamma = 0.01
)

svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Support Vector Machine: ", score)
svm_score = score
# Out:
# Akurasi dengan menggunakan Support Vector Machine:  0.9111111111111111

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(svm, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing SVM:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing SVM: 0.9111111111111111
# Precison :  0.9166666666666666
# Recall :  0.9215686274509803
# F Score :  0.9079365079365079

# %% [markdown]
# ### Hyperparameter SVM

# %% [markdown]
# Saat menggunakan model SVM, beberapa parameter dapat diubah sesuai dengan kebutuhan, antara lain kernel (linear, polynomial, rbf), nilai C, dan nilai Gamma.

# %%
# SVM dengan kernel Linear, nilai parameter C dapat diubah juga.
svmLinear = SVC(
  kernel = 'linear',
      C = 1)

svmLinear.fit(X_train, y_train)
y_pred = svmLinear.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Support Vector Machine Linear Kernel: ", score)
svmlk_score = score
# Out:
# Akurasi dengan menggunakan Support Vector Machine Linear Kernel:  0.9777777777777777

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(svmLinear, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing SVM:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing SVM: 0.9777777777777777
# Precison :  0.9743589743589745
# Recall :  0.9803921568627452
# F Score :  0.9765656565656565

# %%
# SVM dengan kernel polynomial, nilai parameter C, degree, dan gamma dapat diubah juga.
svmPoly = SVC(
  kernel = 'poly',
  C = 1,
  gamma = 0.01,
  degree = 2
)

svmPoly.fit(X_train, y_train)
y_pred = svmPoly.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Support Vector Machine Polynomial Kernel: ", score)
svmpk_score = score
# Out:
# Akurasi dengan menggunakan Support Vector Machine Polynomial Kernel:  0.26666666666666666

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(svmPoly, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing NBC:', accuracy)
# Out:
# Akurasi Testing NBC: 0.26666666666666666

# %%
# SVM dengan kernel RBF, nilai parameter C dan gamma dapat diubah juga.
svmRBF = SVC(
  kernel = 'rbf',
  C = 1,
  gamma = 0.01,
)

svmRBF.fit(X_train, y_train)
y_pred = svmRBF.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Support Vector Machine RBF Kernel: ", score)
svmrbfk_score = score

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi dengan menggunakan Support Vector Machine RBF Kernel:  0.9111111111111111
# Precison :  0.9166666666666666
# Recall :  0.9215686274509803
# F Score :  0.9079365079365079

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(svmRBF, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing NBC:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing NBC: 0.9111111111111111
# Precison :  0.9166666666666666
# Recall :  0.9215686274509803
# F Score :  0.9079365079365079

# %% [markdown]
# ## 2.3 Decision Tree

# %% [markdown]
# Penjelasan lebih lengkap mengenai penggunaan Decision Tree dapat dilihat pada https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

dt = DecisionTreeClassifier(
  max_depth = None,
  min_samples_split = 2
)

dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Decision Tree: ", score)
dt_score = score
# Out:
# Akurasi dengan menggunakan Decision Tree:  0.9777777777777777

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(dt, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing Decision Tree:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing Decision Tree: 0.9777777777777777
# Precison :  0.9743589743589745
# Recall :  0.9803921568627452
# F Score :  0.9765656565656565

# %% [markdown]
# ### Hyperparameter Decision Tree

# %% [markdown]
# Saat menggunakan model Decision Tree, beberapa parameter dapat diubah sesuai dengan kebutuhan, antara max_depth dan min_samples_split.

# %%
# Decision Tree dengan maximal kedalaman adalah max_depth,
# dan minimal jumlah sampel untuk dibentuk leaf baru adalah min_samples_split

dthyp = DecisionTreeClassifier(
  max_depth = 130,
  min_samples_split = 5
)

dthyp.fit(X_train, y_train)
y_pred = dt.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Decision Tree: ", score)
dt_hyper_score = score
# Out:
# Akurasi dengan menggunakan Decision Tree:  0.9777777777777777

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(dt, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing NBC:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing NBC: 0.9777777777777777
# Precison :  0.9743589743589745
# Recall :  0.9803921568627452
# F Score :  0.9765656565656565

# %% [markdown]
# ## 2.4 Naive Bayes

# %% [markdown]
# Penjelasan lebih lengkap mengenai penggunaan Naive Bayes dapat dilihat pada https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.BernoulliNB.html#sklearn.naive_bayes.BernoulliNB

# %%
from sklearn import naive_bayes
from sklearn import metrics

nb = naive_bayes.BernoulliNB()

nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Naive Bayes: ", score)
nb_score = score
# Out:
# Akurasi dengan menggunakan Naive Bayes:  0.7333333333333333

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(nb, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing NBC:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing NBC: 0.7333333333333333
# Precison :  0.7653439153439153
# Recall :  0.7565359477124183
# F Score :  0.7095588235294117

# %% [markdown]
# ## 2.5 K-Nearest Neighbors

# %% [markdown]
# Penjelasan lebih lengkap mengenai penggunaan K-Nearest Neighbors dapat dilihat pada https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

#hilangkan warning
import warnings
warnings.filterwarnings("ignore")
#

knn = KNeighborsClassifier()

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan Nearest Neighbor: ", score)
knn_score = score
# Out:
# Akurasi dengan menggunakan Nearest Neighbor:  1.0

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix

#hilangkan warning
import warnings
warnings.filterwarnings("ignore")
#

plot_confusion_matrix(knn, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing K-NN:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing K-NN: 1.0
# Precison :  1.0
# Recall :  1.0
# F Score :  1.0

# %% [markdown]
# ## 2.6 AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn import metrics

# %%
ab=AdaBoostClassifier(
n_estimators=600,
learning_rate=1
)
ab.fit(X_train, y_train)
y_pred = ab.predict(X_test)
score = metrics.accuracy_score(y_test, y_pred)
print("Akurasi dengan menggunakan AdaBoostClassifier: ", score)
ab_score = score
# Out:
# Akurasi dengan menggunakan AdaBoostClassifier:  0.9777777777777777

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix
plot_confusion_matrix(dt, X_test, y_test)
accuracy = accuracy_score(y_test, y_pred)
print('Akurasi Testing adaBoost:', accuracy)

from sklearn.metrics import precision_recall_fscore_support
P=precision_recall_fscore_support(y_test, y_pred, average='macro')
print("Precison : ",P[0])
print("Recall : ",P[1])
print("F Score : ",P[2])
# Out:
# Akurasi Testing adaBoost: 0.9777777777777777
# Precison :  0.9743589743589745
# Recall :  0.9803921568627452
# F Score :  0.9765656565656565

# %% [markdown]
# ## Perbandingan Hasil Untuk Berbagai Metode Klasifikasi :

# %%
print(f"Algoritma Logistic Regression ({lr_score}) atau ", round(lr_score,3) * 100, "%")
print(f"Algoritma Support Vector Machine ({svm_score}) atau ", round(svm_score,3) * 100, "%")
print(f"Algoritma Support Vector Machine Linear Kernel ({svmlk_score}) atau ", round(svmlk_score,3) * 100, "%")
print(f"Algoritma Support Vector Machine Polynomial Kernel ({svmpk_score}) atau ", round(svmpk_score,3) * 100, "%")
print(f"Algoritma Support Vector Machine RBF Kernel ({svmrbfk_score}) atau ", round(svmrbfk_score,3) * 100, "%")
print(f"Algoritma Decision Tree ({dt_score}) atau ", round(dt_score,3) * 100, "%")
print(f"Algoritma Decision Tree dengan Hyperparameter ({dt_hyper_score}) atau ", round(dt_hyper_score,3) * 100, "%")
print(f"Algoritma Naive Bayes ({nb_score}) atau ", round(nb_score,3) * 100, "%")
print(f"Algoritma K-Nearest Neighbour ({knn_score}) atau ", round(knn_score,3) * 100, "%")
print(f"Algoritma AdaBoostClassifier ({ab_score}) atau ", round(ab_score,3) * 100, "%")

print("\n")

#menentukan hasil terbaik dan terburuk
values = [lr_score, svm_score, svmlk_score, svmpk_score, svmrbfk_score, dt_score, dt_hyper_score, nb_score, knn_score, ab_score]
values_name = ['Logistic Regression','Support Vector Machine','Support Vector Machine Linear Kernel',
               'Support Vector Machine Polynomial Kernel','Support Vector Machine RBF Kernel',
              'Decision Tree','Decision Tree dengan Hyperparameter','Naive Bayes','K-Nearest Neighbour',
              'AdaBoostClassifier']

best_value = max(values)
best_index = values.index(best_value)
poor_value = min(values)
poor_index = values.index(poor_value)

print(f"Berdasarkan hasil di atas: \n - Algoritma terbaik yaitu", values_name[best_index], 
      "dengan akurasi tertinggi", round(best_value*100,2) ,
      "% \n - Algoritma terburuk yaitu", values_name[poor_index],
      "dengan akurasi hanya", round(poor_value*100,2) ,"%" )
# Out:
# Algoritma Logistic Regression (0.9777777777777777) atau  97.8 %
# Algoritma Support Vector Machine (0.9111111111111111) atau  91.10000000000001 %
# Algoritma Support Vector Machine Linear Kernel (0.9777777777777777) atau  97.8 %
# Algoritma Support Vector Machine Polynomial Kernel (0.26666666666666666) atau  26.700000000000003 %
# Algoritma Support Vector Machine RBF Kernel (0.9111111111111111) atau  91.10000000000001 %
# Algoritma Decision Tree (0.9777777777777777) atau  97.8 %
# Algoritma Decision Tree dengan Hyperparameter (0.9777777777777777) atau  97.8 %
# Algoritma Naive Bayes (0.7333333333333333) atau  73.3 %
# Algoritma K-Nearest Neighbour (1.0) atau  100.0 %
# Algoritma AdaBoostClassifier (0.9777777777777777) atau  97.8 %
#
#
# Berdasarkan hasil di atas:
#  - Algoritma terbaik yaitu K-Nearest Neighbour dengan akurasi tertinggi 100.0 %
#  - Algoritma terburuk yaitu Support Vector Machine Polynomial Kernel dengan akurasi hanya 26.67 %

# %% [markdown]
# ---

# %% [markdown]
# ## Modeling

# %%
#import ke pickle
import pickle

pickle.dump(knn, open('knn_model.pkl','wb'))
